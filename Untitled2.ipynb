# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from math import ceil
from datetime import datetime
import statsmodels
from matplotlib.pylab import rcParams

import calendar 
import scipy



# %matplotlib inline

# %%
df = pd.read_csv('/root/Documents/TradingReal/RwandaFinanceData/RwandeseFranc4.csv')

# %%
df.head()
# Out:
#         Years   Price
# 0  2004-01-01  545.37
# 1  2004-01-02  545.37
# 2  2004-01-05  545.43
# 3  2004-01-06  544.97
# 4  2004-01-07  545.23

# %%
df['Years']= pd.to_datetime(df['Years'])

# %%
df.set_index('Years', inplace=True)

# %%
df.head()
# Out:
#              Price
# Years
# 2004-01-01  545.37
# 2004-01-02  545.37
# 2004-01-05  545.43
# 2004-01-06  544.97
# 2004-01-07  545.23

# %%
df['Price']=df['Price'].replace([5.782500], 578.2500)

# %%
df.describe()
# Out:
#              Price
# count  3392.000000
# mean    599.413445
# std      77.413179
# min     505.720000
# 25%     537.402500
# 50%     577.500000
# 75%     654.550000
# max     828.920000

# %%
plt.plot(df)

# %%
df.dtypes
# Out:
# Price    float64
# dtype: object

# %%
rolmean = df.rolling(window=520).mean()
rolstd = df.rolling(window=520).std()

# %%
print(rolmean,rolstd)
# Out:
#                  Price
# Years
# 2004-01-01         NaN
# 2004-01-02         NaN
# 2004-01-05         NaN
# 2004-01-06         NaN
# 2004-01-07         NaN
# 2004-01-08         NaN
# 2004-01-09         NaN
# 2004-01-12         NaN
# 2004-01-13         NaN
# 2004-01-14         NaN
# 2004-01-15         NaN
# 2004-01-16         NaN
# 2004-01-19         NaN
# 2004-01-20         NaN
# 2004-01-21         NaN
# 2004-01-22         NaN
# 2004-01-23         NaN
# 2004-01-26         NaN
# 2004-01-27         NaN
# 2004-01-28         NaN
# 2004-01-29         NaN
# 2004-01-30         NaN
# 2004-02-02         NaN
# 2004-02-03         NaN
# 2004-02-04         NaN
# 2004-02-05         NaN
# 2004-02-06         NaN
# 2004-02-09         NaN
# 2004-02-10         NaN
# 2004-02-11         NaN
# ...                ...
# 2016-11-21  736.650720
# 2016-11-22  736.902509
# 2016-11-23  737.157240
# 2016-11-24  737.411490
# 2016-11-25  737.659451
# 2016-11-28  737.906874
# 2016-11-29  738.154143
# ...

# %%
orig = plt.plot(df,color='blue', label = 'Original')
mean = plt.plot(rolmean, color = 'red', label = 'Mean')
std = plt.plot(rolstd,color = 'black', label= 'StandardDeviation')
plt.legend(loc='best')
plt.title("Rolling mean and Standard Deviation")
plt.show(block=False)

# %%
from statsmodels.tsa.stattools import adfuller

# %%
dftest = adfuller(df['Price'], autolag='AIC')

# %%
dfoutput= pd.Series(dftest[0:4],index=['Test Statistic','p-value', '#Lags-Used', 'Number of Observations used'])

# %%
dfoutput
# Out:
# Test Statistic                    3.645389
# p-value                           1.000000
# #Lags-Used                       24.000000
# Number of Observations used    3367.000000
# dtype: float64

# %%
for key,value in dftest[4].items():
        dfoutput['Critical Value (%s)'%key] = value

# %%
print(dfoutput)
# Out:
# Test Statistic                    3.645389
# p-value                           1.000000
# #Lags-Used                       24.000000
# Number of Observations used    3367.000000
# Critical Value (10%)             -2.567227
# Critical Value (1%)              -3.432294
# Critical Value (5%)              -2.862399
# dtype: float64

# %%
df_trend_log = np.log(df)
plt.plot(df_trend_log)

# %%
##We can do similar rolling average and rolling standard deviation 

logrollingave = df_trend_log.rolling(window=520).mean()
logrollingstd = df_trend_log.rolling(window=520).std()

plt.plot(df_trend_log)
plt.plot(logrollingave,color='red')
#plt.plot(logrollingstd)
#plot(kind='line', x='a',y='b', use_index=False)
plt.show(block=False)

# %%
Logmovingaveragediff = df_trend_log-logrollingave

# %%
Logmovingaveragediff.head(13)
# Out:
#             Price
# Years
# 2004-01-01    NaN
# 2004-01-02    NaN
# 2004-01-05    NaN
# 2004-01-06    NaN
# 2004-01-07    NaN
# 2004-01-08    NaN
# 2004-01-09    NaN
# 2004-01-12    NaN
# 2004-01-13    NaN
# 2004-01-14    NaN
# 2004-01-15    NaN
# 2004-01-16    NaN
# 2004-01-19    NaN

# %%
Logmovingaveragediff.dropna(inplace = True)

# %%
Logmovingaveragediff.head()
# Out:
#                Price
# Years
# 2005-12-28 -0.044917
# 2005-12-29 -0.044781
# 2005-12-30 -0.043827
# 2006-01-02 -0.044139
# 2006-01-03 -0.043713

# %%
plt.plot(Logmovingaveragediff)

# %%
from statsmodels.tsa.stattools import adfuller
def test_stationarity(timeseries):
    
    #Determing rolling statistics
    rolmean = pd.rolling_mean(timeseries, window=520)
    rolstd = pd.rolling_std(timeseries, window=520)

    #Plot rolling statistics:
    orig = plt.plot(timeseries, color='blue',label='Original')
    mean = plt.plot(rolmean, color='red', label='Rolling Mean')
    std = plt.plot(rolstd, color='black', label = 'Rolling Std')
    plt.legend(loc='best')
    plt.title('Rolling Mean & Standard Deviation')
    plt.show(block=False)
    
    #Perform Dickey-Fuller test:
    print ('Results of Dickey-Fuller Test:')
    dftest = adfuller(timeseries['Price'], autolag='AIC')
    dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
    for key,value in dftest[4].items():
        dfoutput['Critical Value (%s)'%key] = value
    print (dfoutput)

# %%
test_stationarity(Logmovingaveragediff)
# Out:
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:5: FutureWarning: pd.rolling_mean is deprecated for DataFrame and will be removed in a future version, replace with
# 	DataFrame.rolling(center=False,window=520).mean()
#   """
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:6: FutureWarning: pd.rolling_std is deprecated for DataFrame and will be removed in a future version, replace with
# 	DataFrame.rolling(center=False,window=520).std()
# Results of Dickey-Fuller Test:
# Test Statistic                   -1.506570
# p-value                           0.530259
# #Lags Used                       17.000000
# Number of Observations Used    2855.000000
# Critical Value (10%)             -2.567309
# Critical Value (1%)              -3.432643
# Critical Value (5%)              -2.862553
# dtype: float64

# %%
expwighted_avg = pd.ewma(df_trend_log, halflife=50)
# Out:
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:1: FutureWarning: pd.ewm_mean is deprecated for DataFrame and will be removed in a future version, replace with
# 	DataFrame.ewm(min_periods=0,ignore_na=False,adjust=True,halflife=50).mean()
#   """Entry point for launching an IPython kernel.

# %%
plt.plot(expwighted_avg, color='red', label = 'WeightedData')
plt.plot(df_trend_log,label='OriginalData')

# %%
ts_log_ewma_diff = df_trend_log - expwighted_avg

# %%
test_stationarity(ts_log_ewma_diff)
# Out:
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:5: FutureWarning: pd.rolling_mean is deprecated for DataFrame and will be removed in a future version, replace with
# 	DataFrame.rolling(center=False,window=520).mean()
#   """
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:6: FutureWarning: pd.rolling_std is deprecated for DataFrame and will be removed in a future version, replace with
# 	DataFrame.rolling(center=False,window=520).std()
# Results of Dickey-Fuller Test:
# Test Statistic                   -3.727549
# p-value                           0.003742
# #Lags Used                       24.000000
# Number of Observations Used    3367.000000
# Critical Value (10%)             -2.567227
# Critical Value (1%)              -3.432294
# Critical Value (5%)              -2.862399
# dtype: float64

# %%
ts_log_diff = df_trend_log - df_trend_log.shift()
plt.plot(ts_log_diff)

# %%
ts_log_diff.dropna(inplace=True)
test_stationarity(ts_log_diff)
# Out:
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:5: FutureWarning: pd.rolling_mean is deprecated for DataFrame and will be removed in a future version, replace with
# 	DataFrame.rolling(center=False,window=520).mean()
#   """
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:6: FutureWarning: pd.rolling_std is deprecated for DataFrame and will be removed in a future version, replace with
# 	DataFrame.rolling(center=False,window=520).std()
# Results of Dickey-Fuller Test:
# Test Statistic                -1.728176e+01
# p-value                        5.776069e-30
# #Lags Used                     2.300000e+01
# Number of Observations Used    3.367000e+03
# Critical Value (10%)          -2.567227e+00
# Critical Value (1%)           -3.432294e+00
# Critical Value (5%)           -2.862399e+00
# dtype: float64

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
decomposition = seasonal_decompose(df_trend_log)

trend = decomposition.trend
seasonal = decomposition.seasonal
residual = decomposition.resid

plt.figure(figsize=(15,8))
plt.subplot(411)
plt.plot(df_trend_log, label='Original')
plt.legend(loc='best')
plt.subplot(412)
plt.plot(trend, label='Trend')
plt.legend(loc='best')
plt.subplot(413)
plt.plot(seasonal,label='Seasonality')
plt.legend(loc='best')
plt.subplot(414)
plt.plot(residual, label='Residuals')
plt.legend(loc='best')
plt.tight_layout()

decopose = residual
decopose.dropna(inplace=True)
test_stationarity(decopose)
# Out:
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:5: FutureWarning: pd.rolling_mean is deprecated for DataFrame and will be removed in a future version, replace with
# 	DataFrame.rolling(center=False,window=520).mean()
#   """
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:6: FutureWarning: pd.rolling_std is deprecated for DataFrame and will be removed in a future version, replace with
# 	DataFrame.rolling(center=False,window=520).std()
# Results of Dickey-Fuller Test:
# Test Statistic                  -21.768832
# p-value                           0.000000
# #Lags Used                       29.000000
# Number of Observations Used    3358.000000
# Critical Value (10%)             -2.567228
# Critical Value (1%)              -3.432299
# Critical Value (5%)              -2.862401
# dtype: float64

# %%
#ACF and PACF plots:
from statsmodels.tsa.stattools import acf, pacf

# %%
lag_acf = acf(ts_log_diff, nlags=20)
lag_pacf = pacf(ts_log_diff, nlags=20, method='ols')

# %%
#Plot ACF: 
plt.figure(figsize=(15,8))
plt.subplot(121) 
plt.plot(lag_acf)
plt.axhline(y=0,linestyle='--',color='gray')
plt.axhline(y=-1.96/np.sqrt(len(ts_log_diff)),linestyle='--',color='gray')
plt.axhline(y=1.96/np.sqrt(len(ts_log_diff)),linestyle='--',color='gray')
plt.title('Autocorrelation Function')

#Plot PACF:
plt.subplot(122)
plt.plot(lag_pacf)
plt.axhline(y=0,linestyle='--',color='gray')
plt.axhline(y=-1.96/np.sqrt(len(ts_log_diff)),linestyle='--',color='gray')
plt.axhline(y=1.96/np.sqrt(len(ts_log_diff)),linestyle='--',color='gray')
plt.title('Partial Autocorrelation Function')
plt.tight_layout()

# %%
from statsmodels.tsa.arima_model import ARIMA

# %%
model = ARIMA(df_trend_log, order=(2, 1, 0))  
results_AR = model.fit(disp=-1) 
plt.figure(figsize=(13,8))
plt.plot(ts_log_diff)
plt.plot(results_AR.fittedvalues, color='red')
plt.title('RSS: %.4f'% sum((results_AR.fittedvalues-ts_log_diff['Price'])**2))
# Out:
# /usr/local/lib/python3.5/dist-packages/statsmodels/tsa/base/tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   % freq, ValueWarning)
# /usr/local/lib/python3.5/dist-packages/statsmodels/tsa/base/tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   % freq, ValueWarning)

# %%
#MA Model 
model = ARIMA(df_trend_log, order=(0, 1, 2))  
results_MA = model.fit(disp=-1)  
plt.figure(figsize=(13,8))
plt.plot(ts_log_diff)
plt.plot(results_MA.fittedvalues, color='red')
plt.title('RSS: %.4f'% sum((results_MA.fittedvalues-ts_log_diff['Price'])**2))
# Out:
# /usr/local/lib/python3.5/dist-packages/statsmodels/tsa/base/tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   % freq, ValueWarning)
# /usr/local/lib/python3.5/dist-packages/statsmodels/tsa/base/tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   % freq, ValueWarning)

# %%
model = ARIMA(df_trend_log, order=(2, 1, 2))  
results_ARIMA = model.fit(disp=-1) 
plt.figure(figsize=(13,8))
plt.plot(ts_log_diff)

plt.plot(results_ARIMA.fittedvalues, color='red')
plt.title('RSS: %.4f'% sum((results_ARIMA.fittedvalues-ts_log_diff['Price'])**2))
# Out:
# /usr/local/lib/python3.5/dist-packages/statsmodels/tsa/base/tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   % freq, ValueWarning)
# /usr/local/lib/python3.5/dist-packages/statsmodels/tsa/base/tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   % freq, ValueWarning)

# %%
predictions_ARIMA_diff = pd.Series(results_ARIMA.fittedvalues, copy=True)
print (predictions_ARIMA_diff.head())
# Out:
# Years
# 2004-01-02    0.000117
# 2004-01-05    0.000162
# 2004-01-06    0.000145
# 2004-01-07    0.000611
# 2004-01-08    0.000248
# dtype: float64

# %%
predictions_ARIMA_diff_cumsum = predictions_ARIMA_diff.cumsum()
print (predictions_ARIMA_diff_cumsum.head())
# Out:
# Years
# 2004-01-02    0.000117
# 2004-01-05    0.000279
# 2004-01-06    0.000425
# 2004-01-07    0.001036
# 2004-01-08    0.001284
# dtype: float64

# %%
predictions_ARIMA_log = pd.Series(df_trend_log['Price'].iloc[0], index=df_trend_log.index)
predictions_ARIMA_log = predictions_ARIMA_log.add(predictions_ARIMA_diff_cumsum,fill_value=0)
predictions_ARIMA_log.head()
# Out:
# Years
# 2004-01-01    6.301464
# 2004-01-02    6.301582
# 2004-01-05    6.301744
# 2004-01-06    6.301889
# 2004-01-07    6.302500
# dtype: float64

# %%
predictions_ARIMA = np.exp(predictions_ARIMA_log)
plt.figure(figsize=(13,8))
plt.plot(df)
plt.plot(predictions_ARIMA)
plt.title('RMSE: %.4f'% np.sqrt(sum((predictions_ARIMA-df['Price'])**2)/len(df)))

# %%
predictions_ARIMA.tail()
# Out:
# Years
# 2016-12-26    810.475740
# 2016-12-27    810.623595
# 2016-12-28    810.806606
# 2016-12-29    811.019623
# 2016-12-30    811.259113
# dtype: float64

# %%
df.head()
# Out:
#              Price
# Years
# 2004-01-01  545.37
# 2004-01-02  545.37
# 2004-01-05  545.43
# 2004-01-06  544.97
# 2004-01-07  545.23

# %%
ts_franc = df['Price']

# %%
plt.plot(df)

# %%
ts_franc_week = ts_franc.resample('W').mean()

# %%
plt.plot(ts_franc_week)

# %%
def check_stationarity(timeseries):
    
    #Determing rolling statistics
    rolling_mean = timeseries.rolling(window=52,center=False).mean() 
    rolling_std = timeseries.rolling(window=52,center=False).std()

    #Plot rolling statistics:
    original = plt.plot(timeseries.index.to_pydatetime(), timeseries.values, color='blue',label='Original')
    mean = plt.plot(rolling_mean.index.to_pydatetime(), rolling_mean.values, color='red', label='Rolling Mean')
    std = plt.plot(rolling_std.index.to_pydatetime(), rolling_std.values, color='black', label = 'Rolling Std')
    plt.legend(loc='best')
    plt.title('Rolling Mean & Standard Deviation')
    plt.show(block=False)
    
    #Perform Dickey-Fuller test:
    print ('Results of Dickey-Fuller Test:')
    dickey_fuller_test = adfuller(timeseries, autolag='AIC')
    dfresults = pd.Series(dickey_fuller_test[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
    for key,value in dickey_fuller_test[4].items():
        dfresults['Critical Value (%s)'%key] = value
    print (dfresults)

# %%
check_stationarity(ts_franc_week)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                   3.656125
# p-value                          1.000000
# #Lags Used                       4.000000
# Number of Observations Used    674.000000
# Critical Value (10%)            -2.569059
# Critical Value (1%)             -3.440089
# Critical Value (5%)             -2.865838
# dtype: float64

# %%
ts_franc_week_log = np.log(ts_franc_week)

# %%
check_stationarity(ts_franc_week_log)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                   3.126742
# p-value                          1.000000
# #Lags Used                       4.000000
# Number of Observations Used    674.000000
# Critical Value (10%)            -2.569059
# Critical Value (1%)             -3.440089
# Critical Value (5%)             -2.865838
# dtype: float64

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
decomposition = seasonal_decompose(ts_franc_week)
ts_franc_week_log_select = ts_franc_week_log[-100:]

trend = decomposition.trend
seasonal = decomposition.seasonal
residual = decomposition.resid

plt.figure(figsize=(15,8))
plt.subplot(411)
plt.plot(ts_franc_week_log[-100:], label='Original')
plt.legend(loc='best')
plt.subplot(412)
plt.plot(trend[-100:], label='Trend')
plt.legend(loc='best')
plt.subplot(413)
plt.plot(seasonal[-100:],label='Seasonality')
plt.legend(loc='best')
plt.subplot(414)
plt.plot(residual[-100:], label='Residuals')
plt.legend(loc='best')
plt.tight_layout()

decopose = residual
decopose.dropna(inplace=True)
#check_stationarity(decomposition )

# %%
ts_franc_week_log_diff = ts_franc_week_log - ts_franc_week_log.shift()
plt.plot( ts_franc_week_log_diff.values)

# %%
ts_franc_week_log_diff.dropna(inplace=True)
check_stationarity(ts_franc_week_log_diff)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                -1.805047e+01
# p-value                        2.640495e-30
# #Lags Used                     3.000000e+00
# Number of Observations Used    6.740000e+02
# Critical Value (10%)          -2.569059e+00
# Critical Value (1%)           -3.440089e+00
# Critical Value (5%)           -2.865838e+00
# dtype: float64
